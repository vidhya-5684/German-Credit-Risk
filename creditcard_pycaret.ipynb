# %%
import pycaret
import pandas as pd

# %%
data = pd.read_csv('german_credit_data.csv')

# %%
from pycaret.classification import *
exp1 = setup(data, target='Risk', normalize=True,normalize_method='minmax',fix_imbalance=True)
# Out:
# <style  type="text/css" >
# #T_d1982fe8_6c79_11eb_a0b7_acde48001122row5_col1,#T_d1982fe8_6c79_11eb_a0b7_acde48001122row29_col1,#T_d1982fe8_6c79_11eb_a0b7_acde48001122row56_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_d1982fe8_6c79_11eb_a0b7_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d1982fe8_6c79_11eb_a0b7_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d1982fe8_6c79_11eb_a0b7_acde48001122row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_d1982fe8_6c79_11eb_a0b7_acde48001122row0_col1" class="data row0 col1" >8974</td>
#             </tr>
#             <tr>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_f0317144_6c79_11eb_a0b7_acde48001122 th {
#           text-align: left;
# ...

# %%
ada = create_model('ada')
# Out:
# <style  type="text/css" >
# #T_0f00c282_6c7a_11eb_a0b7_acde48001122row10_col0,#T_0f00c282_6c7a_11eb_a0b7_acde48001122row10_col1,#T_0f00c282_6c7a_11eb_a0b7_acde48001122row10_col2,#T_0f00c282_6c7a_11eb_a0b7_acde48001122row10_col3,#T_0f00c282_6c7a_11eb_a0b7_acde48001122row10_col4,#T_0f00c282_6c7a_11eb_a0b7_acde48001122row10_col5,#T_0f00c282_6c7a_11eb_a0b7_acde48001122row10_col6{
#             background:  yellow;
#         }</style><table id="T_0f00c282_6c7a_11eb_a0b7_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
ada_tuning = tune_model(ada)
# Out:
# <style  type="text/css" >
# #T_2e1699da_6c7a_11eb_a0b7_acde48001122row10_col0,#T_2e1699da_6c7a_11eb_a0b7_acde48001122row10_col1,#T_2e1699da_6c7a_11eb_a0b7_acde48001122row10_col2,#T_2e1699da_6c7a_11eb_a0b7_acde48001122row10_col3,#T_2e1699da_6c7a_11eb_a0b7_acde48001122row10_col4,#T_2e1699da_6c7a_11eb_a0b7_acde48001122row10_col5,#T_2e1699da_6c7a_11eb_a0b7_acde48001122row10_col6{
#             background:  yellow;
#         }</style><table id="T_2e1699da_6c7a_11eb_a0b7_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
cat = create_model('catboost')
# Out:
# <style  type="text/css" >
# #T_62a9bb00_6c7a_11eb_a0b7_acde48001122row10_col0,#T_62a9bb00_6c7a_11eb_a0b7_acde48001122row10_col1,#T_62a9bb00_6c7a_11eb_a0b7_acde48001122row10_col2,#T_62a9bb00_6c7a_11eb_a0b7_acde48001122row10_col3,#T_62a9bb00_6c7a_11eb_a0b7_acde48001122row10_col4,#T_62a9bb00_6c7a_11eb_a0b7_acde48001122row10_col5,#T_62a9bb00_6c7a_11eb_a0b7_acde48001122row10_col6{
#             background:  yellow;
#         }</style><table id="T_62a9bb00_6c7a_11eb_a0b7_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
cat_tuning = tune_model(cat)
# Out:
# <style  type="text/css" >
# #T_9d38ed72_6c7a_11eb_a0b7_acde48001122row10_col0,#T_9d38ed72_6c7a_11eb_a0b7_acde48001122row10_col1,#T_9d38ed72_6c7a_11eb_a0b7_acde48001122row10_col2,#T_9d38ed72_6c7a_11eb_a0b7_acde48001122row10_col3,#T_9d38ed72_6c7a_11eb_a0b7_acde48001122row10_col4,#T_9d38ed72_6c7a_11eb_a0b7_acde48001122row10_col5,#T_9d38ed72_6c7a_11eb_a0b7_acde48001122row10_col6{
#             background:  yellow;
#         }</style><table id="T_9d38ed72_6c7a_11eb_a0b7_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
GB = create_model('gbc')
# Out:
# <style  type="text/css" >
# #T_557580b8_6c7a_11eb_a0b7_acde48001122row10_col0,#T_557580b8_6c7a_11eb_a0b7_acde48001122row10_col1,#T_557580b8_6c7a_11eb_a0b7_acde48001122row10_col2,#T_557580b8_6c7a_11eb_a0b7_acde48001122row10_col3,#T_557580b8_6c7a_11eb_a0b7_acde48001122row10_col4,#T_557580b8_6c7a_11eb_a0b7_acde48001122row10_col5,#T_557580b8_6c7a_11eb_a0b7_acde48001122row10_col6{
#             background:  yellow;
#         }</style><table id="T_557580b8_6c7a_11eb_a0b7_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
GB.feature_importances_
# Out:
# array([0.11497125, 0.27798447, 0.13468436, 0.0028217 , 0.        ,
#        0.0074752 , 0.00511604, 0.01120235, 0.0010871 , 0.0199275 ,
#        0.00149399, 0.03763134, 0.00681261, 0.02344004, 0.00303152,
#        0.02094021, 0.07293295, 0.02347585, 0.12186782, 0.00738183,
#        0.02213467, 0.01780186, 0.00054437, 0.03532197, 0.01006794,
#        0.00328538, 0.00892779, 0.00763791])

# %%
GB.set_params
# Out:
# <bound method BaseEstimator.set_params of GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=573, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)>

# %%
tune_GB = tune_model(GB)
# Out:
# <style  type="text/css" >
# #T_ecfa403a_6c6c_11eb_a0b7_acde48001122row10_col0,#T_ecfa403a_6c6c_11eb_a0b7_acde48001122row10_col1,#T_ecfa403a_6c6c_11eb_a0b7_acde48001122row10_col2,#T_ecfa403a_6c6c_11eb_a0b7_acde48001122row10_col3,#T_ecfa403a_6c6c_11eb_a0b7_acde48001122row10_col4,#T_ecfa403a_6c6c_11eb_a0b7_acde48001122row10_col5,#T_ecfa403a_6c6c_11eb_a0b7_acde48001122row10_col6{
#             background:  yellow;
#         }</style><table id="T_ecfa403a_6c6c_11eb_a0b7_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
predict_gb = predict_model(GB)
# Out:
# <style  type="text/css" >
# </style><table id="T_74211638_6c72_11eb_a0b7_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_74211638_6c72_11eb_a0b7_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_74211638_6c72_11eb_a0b7_acde48001122row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
# ...

# %%
evaluate_model(GB)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
dt = create_model('dt')
rf = create_model('rf')
ridge = create_model('ridge')
knn = create_model('knn')
# stack trained models
stacked_models = stack_models(estimator_list=[dt,rf,ridge,knn,GB])
# stack trained models dynamically
# Out:
# <style  type="text/css" >
# #T_fdb955cc_6c77_11eb_a0b7_acde48001122row10_col0,#T_fdb955cc_6c77_11eb_a0b7_acde48001122row10_col1,#T_fdb955cc_6c77_11eb_a0b7_acde48001122row10_col2,#T_fdb955cc_6c77_11eb_a0b7_acde48001122row10_col3,#T_fdb955cc_6c77_11eb_a0b7_acde48001122row10_col4,#T_fdb955cc_6c77_11eb_a0b7_acde48001122row10_col5,#T_fdb955cc_6c77_11eb_a0b7_acde48001122row10_col6{
#             background:  yellow;
#         }</style><table id="T_fdb955cc_6c77_11eb_a0b7_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
top7 = compare_models(n_select = 7)
# Out:
# <style  type="text/css" >
#     #T_4cf29d56_6c78_11eb_a0b7_acde48001122 th {
#           text-align: left;
# ...

# %%
top7
# Out:
# [GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                             learning_rate=0.1, loss='deviance', max_depth=3,
#                             max_features=None, max_leaf_nodes=None,
#                             min_impurity_decrease=0.0, min_impurity_split=None,
#                             min_samples_leaf=1, min_samples_split=2,
#                             min_weight_fraction_leaf=0.0, n_estimators=100,
#                             n_iter_no_change=None, presort='deprecated',
#                             random_state=573, subsample=1.0, tol=0.0001,
#                             validation_fraction=0.1, verbose=0,
#                             warm_start=False),
# ...
#  LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                 importance_type='split', learning_rate=0.1, max_depth=-1,
#                 min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
# ...

# %%
stacked_models = stack_models(estimator_list = top7[1:], meta_model = top7[0])
# Out:
# <style  type="text/css" >
# #T_bc181724_6c78_11eb_a0b7_acde48001122row10_col0,#T_bc181724_6c78_11eb_a0b7_acde48001122row10_col1,#T_bc181724_6c78_11eb_a0b7_acde48001122row10_col2,#T_bc181724_6c78_11eb_a0b7_acde48001122row10_col3,#T_bc181724_6c78_11eb_a0b7_acde48001122row10_col4,#T_bc181724_6c78_11eb_a0b7_acde48001122row10_col5,#T_bc181724_6c78_11eb_a0b7_acde48001122row10_col6{
#             background:  yellow;
#         }</style><table id="T_bc181724_6c78_11eb_a0b7_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
stacked_models = stack_models(estimator_list=[cat_tuning,tune_GB,ada_tuning])
# Out:
# <style  type="text/css" >
# #T_20691d5c_6c7b_11eb_a0b7_acde48001122row10_col0,#T_20691d5c_6c7b_11eb_a0b7_acde48001122row10_col1,#T_20691d5c_6c7b_11eb_a0b7_acde48001122row10_col2,#T_20691d5c_6c7b_11eb_a0b7_acde48001122row10_col3,#T_20691d5c_6c7b_11eb_a0b7_acde48001122row10_col4,#T_20691d5c_6c7b_11eb_a0b7_acde48001122row10_col5,#T_20691d5c_6c7b_11eb_a0b7_acde48001122row10_col6{
#             background:  yellow;
#         }</style><table id="T_20691d5c_6c7b_11eb_a0b7_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
prediction_adtuning = predict_model(ada_tuning)
# Out:
# <style  type="text/css" >
# </style><table id="T_ac8b1830_6c7b_11eb_a0b7_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ac8b1830_6c7b_11eb_a0b7_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ac8b1830_6c7b_11eb_a0b7_acde48001122row0_col0" class="data row0 col0" >Ada Boost Classifier</td>
# ...

# %%
pred_ada = predict_model(ada)
# Out:
# <style  type="text/css" >
# </style><table id="T_b603c1d2_6c7b_11eb_a0b7_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b603c1d2_6c7b_11eb_a0b7_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b603c1d2_6c7b_11eb_a0b7_acde48001122row0_col0" class="data row0 col0" >Ada Boost Classifier</td>
# ...

# %%
predict_cat = predict_model(cat)
# Out:
# <style  type="text/css" >
# </style><table id="T_c90cb11c_6c7b_11eb_a0b7_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c90cb11c_6c7b_11eb_a0b7_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c90cb11c_6c7b_11eb_a0b7_acde48001122row0_col0" class="data row0 col0" >CatBoost Classifier</td>
# ...

# %%
predict_cat_tuning = predict_model(cat_tuning)
# Out:
# <style  type="text/css" >
# </style><table id="T_d67b41f6_6c7b_11eb_a0b7_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d67b41f6_6c7b_11eb_a0b7_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d67b41f6_6c7b_11eb_a0b7_acde48001122row0_col0" class="data row0 col0" >CatBoost Classifier</td>
# ...

# %%
predict_stack = predict_model(stacked_models)
# Out:
# <style  type="text/css" >
# </style><table id="T_b15f8386_6c7c_11eb_a0b7_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b15f8386_6c7c_11eb_a0b7_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b15f8386_6c7c_11eb_a0b7_acde48001122row0_col0" class="data row0 col0" >Stacking Classifier</td>
# ...

# %%
evaluate_model(ada_tuning)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…
